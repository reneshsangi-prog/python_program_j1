# %% [markdown]
# # conditional statement in python
# 1. it has a total of 4 types of statements
# 2. 'if statement
# 3. elif
# 4. else
# 5. nested
# '''python syntex -if
# if (condition): (is true then execute the statement inside if block
#
# '''python syntex-ifelse
# if(condition):
# statement 1
# statement 2....
# else:
# statemnt 1
# statement 2....
#
# ''' python - if,else,else
# if(conditon):
# statement 1....
# else(condition):
# statement1....
# else:
# statement1...

# %%
# wap to find a given number is odd?
numbeer=int(input("plz enter a number:"))
if(numbeer%2 == 1):
    print(number,"number is odd")
# Out:
# plz enter a number: 98

# %%
#wap to find a number is odd or even
n=int(input("enter a no"))
if(n%2 == 0):
    print(n,"even")
else:
    print(n,"odd")
# Out:
# enter a no 9087
# 9087 odd

# %%
#wap to find the given number is positive or negative
n=int(input("enter a no"))
if(n>0):
    print("positive")
elif (n<0):
    print("negative")
else:
    print("0")
# Out:
# enter a no 987
# positive

# %%
"""
wap to find the grades based on marks
1. if btw 80-100 A
2. if btw 60-79 B
3. if btw 40-59 c
3. if btw 25-30 d
4. if btw 0-24 fail
other then the ouput - enter a valid statement
"""
n=int(input("enter grade"))
if(n<101 and n>79):
    print("A")
elif (n>59 and n<80):
    print("B")
elif (n>39 and n<60):
     print("c")
elif (
# Out:
# enter grade 100

# %%
#wap to find the largest number from three numbers
a=int(input("1st no"))
b=int(input("2nd no"))
c=int(input("3rd no"))
intd=0
if(a>b):
    d=a
elif(b>a):
    d=b
elif (d>c):
    print(d,"greater")
else:
    print(c,"greater")
# Out:
# 1st no 34
# 2nd no 45
# 3rd no 76

# %%
#wap to predict volidate login creditiols using conditions statements
username=string(imput("enter your username:"))
if (username=="tia@123"):
   pas=string(input("enter password"))
    if (pas == "tia@1234"):
      print("user details validated")
else:
       print("password invalid")
# Out:
#   Cell In[35], line 5
#     if (pas == "tia@1234"):
#     ^
# IndentationError: unexpected indent

# %%
# Program to find even number with number of digits

num = int(input("Enter a number: "))

if num % 2 == 0:  # check if even
    if 1 <= num <= 9:
        print("1 digit even num")
    elif 10 <= num <= 99:
        print("2 digit even num")
    elif 100 <= num <= 999:
        print("3 digit even num")
    elif 1000 <= num <= 9999:
        print("4 digit even num")
    else:
        print("weird even num")
else:
    print("The num is not even")
