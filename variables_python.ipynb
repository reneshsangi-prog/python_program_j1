# %% [markdown]
# # variables in python
# 1. variables is memory allocate in memory
# 2. variables are name "
# # key points in define variables
# 1. variables don't start with digitd
# 2. variables doesn't allow special character
# 3.

# %%
name="vikas"
age=20
s=200000
print(name)
print(age)
print(s)
