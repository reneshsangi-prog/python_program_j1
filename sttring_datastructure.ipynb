# %% [markdown]
# # strings in python
# 1.string is a collection of info or data enclosed by double or single quates

# %%
n="shivaji"
info = "wt ti"
print(n)
print(info)
print(type(n))
print(type(info))
# Out:
# shivaji
# wt ti
# <class 'str'>
# <class 'str'>

# %%
info1=''' my slef r 
hi '''
print(info1)
# Out:
#  my slef r
# hi

# %%
a='ab'
b='cd'
print(a+b)
# Out:
# abcd

# %%
n="python program"
print(n*10)
# Out:
# python programpython programpython programpython programpython programpython programpython programpython programpython programpython program

# %%
data="python programming"
print(data)
print(data[0])
# Out:
# python programming
# p

# %%
data="python programming"
print(data)
print(data[7:10])
# Out:
# python programming
# pro

# %%
data="python programming"
print(data)
print(data[7:14])
# Out:
# python programming
# program
